# %% [markdown]
# <a href="https://colab.research.google.com/github/NaNa-003/STAT-7220-Applied-Experimental-Design/blob/assignment-1/Homework1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
